# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam # Import optimizer
from scikeras.wrappers import KerasClassifier # Wrapper untuk Keras di Scikit-learn

# %%
df = pd.read_csv('features_selected/Combined_selected_features.csv')

df
# Out:
#      TCD_Max     TCD_AUC  TCD_Mean  TVOC_Skew  TVOC_Decay  TVOC_Kurtosis  \
# 0   4.653726  -48.900164 -0.155963   2.145402    0.181673       3.805084
# 1   5.017747   66.527975  0.212078   1.899005    0.201204       2.544621
# 2   6.416043  161.938268  0.514387   2.112537    0.130841       3.601863
# 3   6.045575  -27.786546 -0.090326   2.126913    0.170684       3.671346
# 4   6.633381  936.930212  2.969637   2.081987    0.149772       3.417740
# ..       ...         ...       ...        ...         ...            ...
# 75  9.218774   50.246577  0.159674   2.115171    0.165337       3.673264
# 76  3.632113  -98.794463 -0.313750   5.456874    0.663833      29.722503
# 77  1.769671 -277.043813 -0.895336   5.442858    0.812571      29.091908
# 78  7.703725  170.744481  0.541235   2.191213    0.168066       4.055420
# 79  3.982960  -31.896631 -0.103635   5.901759    0.777859      35.428672
#
#       Label
# 0    butana
# 1    butana
# 2    butana
# 3    butana
# 4    butana
# ..      ...
# 75   butana
# 76  spirtus
# 77  spirtus
# 78   butana
# 79  spirtus
#
# [80 rows x 7 columns]

# %%
# Separate features (X) and target (y)
X = df.drop('Label', axis=1).values
y = df['Label'].values

# Encode the target variable (Label)
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Normalisasi
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_scaled
# Out:
# array([[0.38506345, 0.33694247, 0.33890323, 0.04471949, 0.0612923 ,
#         0.02226172],
#        [0.42322545, 0.41457803, 0.41674774, 0.        , 0.08484111,
#         0.        ],
#        [0.56981528, 0.47874983, 0.4806892 , 0.03875463, 0.        ,
#         0.01867253],
#        [0.53097746, 0.35114323, 0.35278606, 0.04136388, 0.04804108,
#         0.0198997 ],
#        [0.59259984, 1.        , 1.        , 0.03321014, 0.02282633,
#         0.01542063],
#        [0.38775598, 0.32780149, 0.32972296, 0.03836713, 0.05433586,
#         0.01793439],
#        [0.72637335, 0.        , 0.        , 0.01237104, 0.05541114,
#         0.00471311],
#        [0.22829084, 0.37268827, 0.3746801 , 0.65123194, 0.72792134,
#         0.47600511],
#        [0.37846354, 0.3998499 , 0.40171754, 0.01548756, 0.09911181,
#         0.00633471],
#        [0.55638751, 0.40370631, 0.40550603, 0.01078321, 0.07804691,
#         0.00373893],
#        [0.2798672 , 0.43226936, 0.4352996 , 0.71665486, 0.66012702,
#         0.55975855],
#        [0.59313352, 0.40884359, 0.41047885, 0.04270198, 0.03687055,
#         0.0197912 ],
#        [0.04471364, 0.31266771, 0.31407912, 0.64323047, 0.594754  ,
#         0.49287176],
#        [0.58261551, 0.41040276, 0.41226294, 0.04713362, 0.04195516,
#         0.0232988 ],
#        [0.12362021, 0.33726847, 0.33922419, 0.93700814, 0.39218728,
#         0.89118807],
#        [0.20960406, 0.50372874, 0.50672531, 0.95661966, 0.39464301,
#         0.91213015],
#        [0.31842074, 0.4007398 , 0.40265803, 0.66008752, 0.58585045,
#         0.51160007],
#        [0.27730072, 0.38355772, 0.38560636, 0.71854953, 0.67922322,
#         0.57093016],
#        [0.26410358, 0.25878394, 0.25991324, 0.91829918, 0.72152738,
#         0.8565727 ],
#        [0.11935079, 0.38871766, 0.39078226, 0.68403033, 0.62682147,
#         0.52978073],
#        [0.62173223, 0.07017937, 0.07186504, 0.02553546, 0.01933263,
#         0.01118713],
#        [0.18812017, 0.34559787, 0.34756799, 0.94248879, 0.87150295,
#         0.88528709],
#        [0.34208494, 0.37806192, 0.38003948, 0.00926772, 0.00616799,
#         0.00275024],
#        [0.15081366, 0.34064435, 0.34197795, 0.80474031, 0.92428035,
#         0.69836246],
#        [0.81013935, 0.37551041, 0.37747924, 0.04938571, 0.03429187,
#         0.02281843],
#        [0.        , 0.2354787 , 0.23706223, 0.85364409, 0.68824662,
#         0.76552241],
#        [0.22696871, 0.38746818, 0.38944769, 0.70770032, 0.64597837,
#         0.56038607],
#        [0.01617393, 0.2956305 , 0.29763019, 0.77336884, 0.54152488,
#         0.68136114],
#        [0.85174478, 0.51819062, 0.52018538, 0.02573557, 0.0546017 ,
#         0.01185027],
#        [0.58320282, 0.43139932, 0.43361071, 0.04745548, 0.0504745 ,
#         0.02139906],
#        [0.2273388 , 0.00980516, 0.00217561, 0.61355094, 0.59312991,
#         0.44189863],
#        [0.30814141, 0.31928928, 0.32124151, 0.69056541, 1.        ,
#         0.53397868],
#        [0.40810011, 0.30847716, 0.31019939, 0.02387201, 0.13548404,
#         0.01041989],
#        [0.11235398, 0.22493392, 0.22640727, 0.72848066, 0.92586295,
#         0.58507459],
#        [0.14836518, 0.35191811, 0.35378953, 0.66001783, 0.66548793,
#         0.52194999],
#        [0.87628324, 0.46949857, 0.47162358, 0.04711014, 0.07949941,
#         0.0236737 ],
#        [0.26575825, 0.36140806, 0.36339616, 0.64692356, 0.58324172,
#         0.50914789],
#        [0.76217269, 0.36260818, 0.36450927, 0.04577665, 0.05338295,
#         0.02246663],
#        [0.07035432, 0.32303209, 0.32455462, 0.68704133, 0.55765652,
#         0.56612634],
#        [0.42984145, 0.44822354, 0.4497715 , 0.02841107, 0.06854335,
#         0.01256006],
#        [0.18320711, 0.30995588, 0.31190163, 0.64251749, 0.60103459,
#         0.47847467],
#        [0.32157722, 0.4064453 , 0.40879722, 0.01354155, 0.08070931,
#         0.00648184],
#        [0.93868603, 0.87934621, 0.87975612, 0.02832595, 0.05623288,
#         0.01314134],
#        [0.59707577, 0.20700557, 0.20896136, 0.03637901, 0.06435694,
#         0.01629244],
#        [0.31644694, 0.38905844, 0.39120796, 0.02393363, 0.09309261,
#         0.01070049],
#        [0.2565865 , 0.33363234, 0.33557006, 0.73106498, 0.64395841,
#         0.59479283],
#        [0.49484826, 0.33535441, 0.33694255, 0.03169474, 0.11643953,
#         0.01527647],
#        [0.51760333, 0.36833039, 0.37022411, 0.04346275, 0.0726685 ,
#         0.0212777 ],
#        [0.33280055, 0.49796507, 0.49974583, 0.99264518, 0.30788999,
#         0.95849393],
#        [0.2740611 , 0.38836807, 0.39035327, 0.95211278, 0.70706948,
#         0.90107654],
#        [0.04217666, 0.32178337, 0.32290426, 0.93449699, 0.69158661,
#         0.87756858],
#        [0.05665301, 0.36688863, 0.36862354, 0.78647666, 0.54262903,
#         0.70089069],
#        [0.47198324, 0.38985776, 0.39170688, 0.03500617, 0.05934445,
#         0.01725874],
#        [0.52325656, 0.42637104, 0.42841811, 0.03747138, 0.0373957 ,
#         0.01832119],
#        [0.24391232, 0.31394227, 0.31588925, 0.60107499, 0.69534473,
#         0.44064836],
#        [0.62360681, 0.516049  , 0.51762293, 0.03370485, 0.02701144,
#         0.0159692 ],
#        [0.30695337, 0.33500443, 0.33648506, 0.63299793, 0.61050822,
#         0.46009003],
#        [1.        , 0.42496494, 0.42686131, 0.04773315, 0.04764202,
#         0.02356033],
#        [0.14596496, 0.27837657, 0.28029682, 0.66051862, 0.6698464 ,
#         0.4974783 ],
#        [0.1752368 , 0.35601612, 0.35799828, 0.6671618 , 0.65629346,
#         0.5047192 ],
#        [0.29797739, 0.38053748, 0.38258286, 0.7329455 , 0.749915  ,
#         0.5934317 ],
#        [0.51643943, 0.35258749, 0.35413011, 0.02091014, 0.05918706,
#         0.00970916],
#        [0.69480589, 0.41390095, 0.41595757, 0.03641636, 0.047387  ,
#         0.01761252],
#        [0.30528261, 0.30800745, 0.30991364, 0.95620235, 0.46828148,
#         0.91311692],
#        [0.08749638, 0.29735868, 0.29953068, 0.64949026, 0.86567559,
#         0.47505262],
#        [0.13286706, 0.30525039, 0.30740234, 0.64149772, 0.84560369,
#         0.46786904],
#        [0.09168267, 0.32177091, 0.32385192, 0.63682425, 0.74669645,
#         0.46333139],
#        [0.35550466, 0.3397393 , 0.34261081, 0.04495159, 0.09224008,
#         0.02188134],
#        [0.61208848, 0.36763269, 0.36943038, 0.05276305, 0.0326209 ,
#         0.0259176 ],
#        [0.31610635, 0.51031725, 0.51350528, 0.00788417, 0.07006925,
#         0.0040726 ],
#        [0.18651377, 0.35655271, 0.35828873, 1.        , 0.76660863,
#         1.        ],
#        [0.51513876, 0.41818719, 0.4204026 , 0.03910553, 0.01365905,
#         0.01887119],
#        [0.34952961, 0.42190449, 0.42445544, 0.00944297, 0.07508664,
#         0.00516817],
#        [0.43220412, 0.3703619 , 0.37231349, 0.03841263, 0.00255529,
#         0.01801972],
#        [0.0632261 , 0.36531685, 0.36732205, 0.63790043, 0.69708608,
#         0.46474763],
#        [0.86363856, 0.40362736, 0.40566367, 0.03923265, 0.04159466,
#         0.01993357],
#        [0.27796312, 0.30338417, 0.30552959, 0.64573043, 0.64266503,
#         0.48000346],
#        [0.08271473, 0.18349582, 0.18251818, 0.64318669, 0.82200855,
#         0.46886618],
#        [0.704809  , 0.48467279, 0.48636768, 0.0530339 , 0.04488505,
#         0.02668305],
#        [0.314744  , 0.34837884, 0.34997105, 0.72647437, 0.7801542 ,
#         0.58078323]])

# %%
import tensorflow as tf

def create_model(lr, hidden_units,hidden_units1):
    model = Sequential()
    model.add(tf.keras.Input(shape=(X_scaled.shape[1],)))
    model.add(Dense(hidden_units, activation='relu'))
    model.add(Dense(hidden_units1, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=Adam(learning_rate=lr), loss='binary_crossentropy', metrics=['accuracy'], )
    return model

# parameter
param_grid = {
    'model__lr': [0.001, 0.01],
    'model__hidden_units': [32],
    'model__hidden_units1': [16],
    'batch_size': [32],
    'epochs': [100, 120]
}

# keras clasifier
keras_model = KerasClassifier(model=create_model, verbose=0)

# cross validation
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42) # Menggunakan 3 fold untuk contoh ini

# grid search
grid_search = GridSearchCV(
    estimator=keras_model,
    param_grid=param_grid,
    cv=cv_strategy,
    scoring='accuracy',
    n_jobs=-1 #core cpu
)

# running
print("Memulai GridSearchCV...")
grid_search.fit(X_scaled, y_encoded)
print("GridSearchCV selesai.")

# coba print hasil
print("\n--- Hasil GridSearchCV ---")
print(f"Best parameters found: {grid_search.best_params_}")
print(f"Best validation accuracy: {grid_search.best_score_:.4f}")

# best model
best_model = grid_search.best_estimator_
# Out:
# Memulai GridSearchCV...
# GridSearchCV selesai.
#
# --- Hasil GridSearchCV ---
# Best parameters found: {'batch_size': 32, 'epochs': 100, 'model__hidden_units': 32, 'model__hidden_units1': 16, 'model__lr': 0.001}
# Best validation accuracy: 1.0000

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np # Pastikan numpy diimpor

# Asumsi X_scaled dan y sudah ada dari langkah sebelumnya
# Asumsi best_model = grid_search.best_estimator_ sudah didefinisikan

# 1. Lakukan prediksi menggunakan model terbaik
# best_model.predict mengembalikan probabilitas, perlu diubah ke kelas biner (0 atau 1)
y_pred_prob = best_model.predict(X_scaled)

y_pred_prob

# Konversi probabilitas menjadi label kelas biner (0 atau 1)
# Untuk klasifikasi biner dengan sigmoid, ambang batas umum adalah 0.5
y_pred = (y_pred_prob > 0.5).astype(int)

# 2. Hitung Confusion Matrix
cm = confusion_matrix(y_encoded, y_pred)

# 3. Tampilkan Confusion Matrix
# Dapatkan nama kelas (jika tidak ada, gunakan 0 dan 1)
class_names = ['Butana', 'Metanol'] # Sesuaikan ini jika Anda memiliki nama kelas sebenarnya

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix for Best Model (on full dataset)')
plt.show()

# Opsional: Tampilkan metrik klasifikasi lainnya
from sklearn.metrics import classification_report
print("\n--- Classification Report (on full dataset) ---")
print(classification_report(y_encoded, y_pred, target_names=class_names))
# Out:
# --- Classification Report (on full dataset) ---
#               precision    recall  f1-score   support
#
#       Butana       1.00      1.00      1.00        40
#      Metanol       1.00      1.00      1.00        40
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %%
# Extract best parameters from grid_search
best_params = grid_search.best_params_
best_lr = best_params['model__lr']
best_hidden_units = best_params['model__hidden_units']
best_hidden_units1 = best_params['model__hidden_units1']
best_batch_size = best_params['batch_size']
best_epochs = best_params['epochs']

# Create a new model instance with the best parameters
# This ensures we get a fresh training history
final_model = create_model(
    lr=best_lr,
    hidden_units=best_hidden_units,
    hidden_units1=best_hidden_units1
)

# Train the final model on the full data, capturing the history
print(f"Melatih model terakhir dengan hyperparameter terbaik (Epochs: {best_epochs}, Batch Size: {best_batch_size})...")
history = final_model.fit(
    X_scaled, y_encoded,
    epochs=best_epochs,
    batch_size=best_batch_size,
    verbose=1 # Set verbose to 1 to see training progress and capture history
)
print("Pelatihan model terakhir selesai.")

# Plot Akurasi vs Epoch
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1) # 1 row, 2 columns, first plot
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy vs. Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent overlap

# Plot Fungsi Loss vs Epoch
plt.subplot(1, 2, 2) # 1 row, 2 columns, second plot
plt.plot(history.history['loss'])
plt.title('Model Loss vs. Epoch')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.grid(True)
plt.tight_layout() # Adjust layout to prevent overlap

plt.show() # Display the plots
# Out:
# Melatih model terakhir dengan hyperparameter terbaik (Epochs: 100, Batch Size: 32)...
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5125 - loss: 0.6809
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7250 - loss: 0.6609
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9625 - loss: 0.6420
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9750 - loss: 0.6229
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9875 - loss: 0.6045
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.5864
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.5679
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.5499
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.5314
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.5131
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.4943
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.4756
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.4569
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.4381
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.4194
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.4005
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.3819
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.3635
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.3455
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.3277
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.3099
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.2925
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.2752
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.2585
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.2424
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.2267
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.2116
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1971
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1831
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1702
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1578
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1462
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1354
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1255
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1161
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1075
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0987
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0908
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0835
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0769
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0708
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0653
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0605
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0560
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0519
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0483
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0420
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0392
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0345
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0258
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0232
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0221
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0210
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0200
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0191
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0182
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0174
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0167
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0160
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0147
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0113
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0110
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0106
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0102
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0099
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0096
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0093
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0090
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0087
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0085
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0082
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0077
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0075
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0073
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0067
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0066
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0064
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0062
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0061
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0059
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0058
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0056
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 1.0000 - loss: 0.0055
# Pelatihan model terakhir selesai.
