# %% [markdown]
# # Data Raw

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/raw/butana/propana_raw_120_{i}.csv')
    data.to_csv(f'Data/raw/butana2/butana_raw_{i}.csv', index=False)

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/raw/spirtus/spirtus_raw_120_{i}.csv')
    data.to_csv(f'Data/raw/spirtus2/spirtus_raw_{i}.csv', index=False)

# %% [markdown]
# # Data trimmed

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/trimmed/propana/propana_trimmed_120_{i}.csv')
    data.to_csv(f'Data/trimmed/butana2/butana_trimmed_{i}.csv', index=False)

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/trimmed/spirtus/spirtus_trimmed_120_{i}.csv')
    data.to_csv(f'Data/trimmed/spirtus2/spirtus_trimmed_{i}.csv', index=False)

# %% [markdown]
# # Data Filtered

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/filtered/propana/propana_filtered_120_{i}.csv')
    data.to_csv(f'Data/filtered/butana2/butana_filtered_{i}.csv', index=False)

# %%
import pandas as pd

for i in range (1, 41) :
    data = pd.read_csv(f'Data/filtered/spirtus/spirtus_filtered_120_{i}.csv')
    data.to_csv(f'Data/filtered/spirtus2/spirtus_filtered_{i}.csv', index=False)
